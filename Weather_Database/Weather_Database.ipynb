# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities=[]


# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 737

# %%
cities
# Out:
# ['albany',
#  'barcelos',
#  'saskylakh',
#  'rikitea',
#  'krutinka',
#  'kapaa',
#  'karpogory',
#  'pisco',
#  'rio grande',
#  'cabo san lucas',
#  'bredasdorp',
#  'ortakoy',
#  'barentsburg',
#  'husavik',
#  'namibe',
#  'severo-kurilsk',
#  'samusu',
#  'sorland',
#  'port alfred',
#  'puli',
#  'sao raimundo nonato',
#  'clyde river',
#  'hermanus',
#  'zhangjiakou',
#  'la paz',
#  'puerto ayora',
#  'sarankhola',
#  'hobart',
#  'vaini',
#  'mar del plata',
#  'lebu',
#  'san jose de guanipa',
#  'ushuaia',
#  'narsaq',
#  'erzin',
#  'scarborough',
#  'dikson',
#  'tucuman',
#  'busselton',
#  'lompoc',
#  'half moon bay',
#  'atuona',
#  'vao',
#  'panguna',
#  'progreso',
#  'acapulco',
#  'maceio',
#  'souillac',
#  'chokurdakh',
#  'katsuura',
#  'yellowknife',
#  'butaritari',
#  'illoqqortoormiut',
#  'pevek',
#  'hithadhoo',
#  'mataura',
#  'kentau',
#  'hilo',
#  'sabha',
#  'port hedland',
#  'cape town',
#  'qaanaaq',
#  'bilma',
#  'cayenne',
#  'punta arenas',
#  'uaua',
#  'nanortalik',
#  'tuktoyaktuk',
#  'quatre cocos',
#  'constitucion',
#  'warwick',
#  'cockburn town',
#  'maniwaki',
#  'asau',
#  'mitu',
#  'ribeira grande',
#  'preobrazheniye',
#  'ponta do sol',
#  'jangaon',
#  'ritchie',
#  'raudeberg',
#  'puchezh',
#  'krasnokamensk',
#  'carnarvon',
#  'yinchuan',
#  'chicama',
#  'wuning',
#  'mashhad',
#  'inirida',
#  'ikalamavony',
#  'bluff',
#  'tazovskiy',
#  'tasiilaq',
#  'thompson',
#  'urdzhar',
#  'jamestown',
#  'saleaula',
#  'salalah',
#  'taolanaro',
#  'moerai',
#  'tuatapere',
#  'noumea',
#  'marsa matruh',
#  'torbay',
#  'camana',
#  'kisangani',
#  'plymouth',
#  'altea',
#  'naze',
#  'avera',
#  'cidreira',
#  'vila',
#  'vaitupu',
#  'palabuhanratu',
#  'sorong',
#  'shimoda',
#  'belushya guba',
#  'iqaluit',
#  'whitianga',
#  'nikolskoye',
#  'inta',
#  'kristiinankaupunki',
#  'miramar',
#  'hobyo',
#  'fairbanks',
#  'longyearbyen',
#  'pemba',
#  'mount gambier',
#  'bambanglipuro',
#  'dawlatabad',
#  'bengkulu',
#  'new norfolk',
#  'hofn',
#  'bambous virieux',
#  'correntina',
#  'belyy gorodok',
#  'celestun',
#  'asfi',
#  'nguruka',
#  'alofi',
#  'namatanai',
#  'tiksi',
#  'aklavik',
#  'paita',
#  'kansanshi',
#  'alice springs',
#  'cape canaveral',
#  'vigeland',
#  'klyuchi',
#  'victoria',
#  'barrow',
#  'luderitz',
#  'shelburne',
#  'nanakuli',
#  'bandarbeyla',
#  'mehar',
#  'sitka',
#  'encruzilhada do sul',
#  'dingle',
#  'ketchikan',
#  'vostok',
#  'mahebourg',
#  'castro',
#  'mogzon',
#  'isangel',
#  'berbera',
#  'cheyur',
#  'kaitangata',
#  'korla',
#  'kloulklubed',
#  'vardo',
#  'tyrma',
#  'sotouboua',
#  'mayo',
#  'grand river south east',
#  'ijaki',
#  'monrovia',
#  'sentyabrskiy',
#  'diego de almagro',
#  'ballina',
#  'cherskiy',
#  'faanui',
#  'arraial do cabo',
#  'khatanga',
#  'ostrovnoy',
#  'lolua',
#  'kenai',
#  'hibbing',
#  'ust-kuyga',
#  'isiro',
#  'rungata',
#  'vanavara',
#  'chebarkul',
#  'chapeltown',
#  'gladstone',
#  'avarua',
#  'miles city',
#  'shenzhen',
#  'port elizabeth',
#  'saint-philippe',
#  'naryan-mar',
#  'grindavik',
#  'sioux lookout',
#  'mys shmidta',
#  'coquimbo',
#  'khonuu',
#  'nelson bay',
#  'lagoa',
#  'dalbandin',
#  'nara',
#  'upernavik',
#  'tsiroanomandidy',
#  'santa rosa',
#  'port keats',
#  'puntarenas',
#  'provideniya',
#  'cabedelo',
#  'bartica',
#  'iquique',
#  'gat',
#  'fortuna',
#  'kastamonu',
#  'lorengau',
#  'silver city',
#  'cairns',
#  'the pas',
#  'sur',
#  'te anau',
#  'broome',
#  'bethel',
#  'solnechnyy',
#  'ratnagiri',
#  'georgetown',
#  'warrington',
#  'hovd',
#  'saint george',
#  'meyungs',
#  'chuy',
#  'san pedro',
#  'talcahuano',
#  'kjustendil',
#  'lima',
#  'kupang',
#  'laguna',
#  'sturgeon bay',
#  'ribas do rio pardo',
#  'falealupo',
#  'talnakh',
#  'homa bay',
#  'taseyevo',
#  'ardatov',
#  'hasaki',
#  'saint-augustin',
#  'san isidro',
#  'nicoya',
#  'east london',
#  'ngukurr',
#  'takhtamygda',
#  'hualmay',
#  'saint-pierre',
#  'belmonte',
#  'kangaatsiaq',
#  'kruisfontein',
#  'vestmannaeyjar',
#  'kemijarvi',
#  'sao joao da barra',
#  'grand centre',
#  'porto novo',
#  'kamenskoye',
#  'alta floresta',
#  'pascagoula',
#  'sinnamary',
#  'morges',
#  'mayya',
#  'buala',
#  'mormugao',
#  'saldanha',
#  'mae sai',
#  'kobryn',
#  'samarai',
#  'suicheng',
#  'coos bay',
#  'hay river',
#  'deputatskiy',
#  'deder',
#  'airai',
#  'yekaterinoslavka',
#  'yaan',
#  'seoul',
#  'asosa',
#  'codrington',
#  'san quintin',
#  'labutta',
#  'baijiantan',
#  'mirabad',
#  'aybak',
#  'muli',
#  'kitui',
#  'beringovskiy',
#  'nyurba',
#  'walla walla',
#  'tateyama',
#  'priargunsk',
#  'shirokiy',
#  'kalmunai',
#  'yumen',
#  'charleville-mezieres',
#  'sao gabriel da cachoeira',
#  'port lincoln',
#  'nizhneyansk',
#  'kodiak',
#  'puerto colombia',
#  'mantua',
#  'ahipara',
#  'nome',
#  'sakaiminato',
#  'chernukha',
#  'north myrtle beach',
#  'la ronge',
#  'bilibino',
#  'ternate',
#  'tsihombe',
#  'bowen',
#  'paranaiba',
#  'dharchula',
#  'grand gaube',
#  'norman wells',
#  'carutapera',
#  'port macquarie',
#  'houma',
#  'itaqui',
#  'marawi',
#  'xichang',
#  'puerto baquerizo moreno',
#  'mineral wells',
#  'kahului',
#  'minsk',
#  'san andres',
#  'turbat',
#  'irbil',
#  'kapuskasing',
#  'brae',
#  'benguela',
#  'kim',
#  'marzuq',
#  'kasongo-lunda',
#  'ust-nera',
#  'gushikawa',
#  'manta',
#  'aksu',
#  'touros',
#  'plettenberg bay',
#  'merauke',
#  'achisay',
#  'parana',
#  'barreirinhas',
#  'petrolia',
#  'kerteh',
#  'barreirinha',
#  'ampanihy',
#  'leningradskiy',
#  'jawhar',
#  'batsfjord',
#  'itaituba',
#  'bure',
#  'sao filipe',
#  'waddan',
#  'praia da vitoria',
#  'mufumbwe',
#  'ust-kamchatsk',
#  'lavrentiya',
#  'gannan',
#  'ilulissat',
#  'buchanan',
#  'okhotsk',
#  'trapani',
#  'falam',
#  'pontianak',
#  'yangliuqing',
#  'necochea',
#  'faya',
#  'vagur',
#  'mitsamiouli',
#  'anadyr',
#  'mapiripan',
#  'tsaratanana',
#  'hokitika',
#  'portland',
#  'barcelona',
#  'afmadu',
#  'gemena',
#  'flinders',
#  'plerin',
#  'simao',
#  'ayagoz',
#  'atambua',
#  'dicabisagan',
#  'thohoyandou',
#  'pudozh',
#  'tautira',
#  'kudahuvadhoo',
#  'madang',
#  'tilichiki',
#  'poya',
#  'charters towers',
#  'krasnyy luch',
#  'lazaro cardenas',
#  'ohara',
#  'arman',
#  'davila',
#  'noyabrsk',
#  'taber',
#  'otane',
#  'atar',
#  'pasni',
#  'mount isa',
#  'kitale',
#  'zapolyarnyy',
#  'dubti',
#  'mackenzie',
#  'kavieng',
#  'ramnagar',
#  'galesong',
#  'ust-kulom',
#  'sal rei',
#  'sosva',
#  'puerto escondido',
#  'kuloy',
#  'kambove',
#  'gizo',
#  'doha',
#  'calama',
#  'taoudenni',
#  'labuhan',
#  'tungor',
#  'verkhoyansk',
#  'douglas',
#  'kaseda',
#  'santa cruz',
#  'riosucio',
#  'cap malheureux',
#  'obera',
#  'nishihara',
#  'poum',
#  'kongolo',
#  'pangnirtung',
#  'abha',
#  'vila velha',
#  'tessalit',
#  'berdigestyakh',
#  'hongjiang',
#  'goteborg',
#  'vanderhoof',
#  'ahuimanu',
#  'jumla',
#  'ndele',
#  'oranjemund',
#  'mirador',
#  'nouakchott',
#  'roma',
#  'novobirilyussy',
#  'senneterre',
#  'morondava',
#  'omboue',
#  'aswan',
#  'sawakin',
#  'kharan',
#  'san giovanni rotondo',
#  'pacific grove',
#  'baiyin',
#  'haines junction',
#  'methoni',
#  'auch',
#  'dunedin',
#  'karaul',
#  'camacha',
#  'verkhnyaya inta',
#  'chute-aux-outardes',
#  'srednekolymsk',
#  'aquiraz',
#  'kodinsk',
#  'grand-santi',
#  'tomatlan',
#  'kavos',
#  'pine bluff',
#  'tukrah',
#  'manturovo',
#  'othonoi',
#  'bolungarvik',
#  'bathsheba',
#  'honiara',
#  'jega',
#  'belaya gora',
#  'smolenskoye',
#  'roald',
#  'tadine',
#  'nuevitas',
#  'bien hoa',
#  'hamilton',
#  'nizwa',
#  'coihaique',
#  'ouadda',
#  'mabaruma',
#  'botou',
#  'mareeba',
#  'tubmanburg',
#  'nuqui',
#  'havre-saint-pierre',
#  'chapais',
#  'curup',
#  'marcona',
#  'bud',
#  'beinamar',
#  'berlevag',
#  'tabiauea',
#  'terracina',
#  'ostersund',
#  'yulara',
#  'san patricio',
#  'rawson',
#  'jibuti',
#  'mandalgovi',
#  'north bend',
#  'tignere',
#  'doka',
#  'port-cartier',
#  'nantucket',
#  'liuhe',
#  'kavaratti',
#  'port alberni',
#  'esperance',
#  'saint anthony',
#  'zhigansk',
#  'changtu',
#  'hatillo',
#  'noshiro',
#  'angermunde',
#  'morant bay',
#  'malakal',
#  'osypenko',
#  'sandusky',
#  'buariki',
#  'padre bernardo',
#  'tura',
#  'novyy starodub',
#  'curuca',
#  'botshabelo',
#  'nampula',
#  'tubinskiy',
#  'kieta',
#  'yokadouma',
#  'skibbereen',
#  'satitoa',
#  'shingu',
#  'baracoa',
#  'lucapa',
#  'lumphat',
#  'camacupa',
#  'chengde',
#  'kununurra',
#  'kaeo',
#  'hurghada',
#  'asyut',
#  'pasighat',
#  'the valley',
#  'springbok',
#  'vestmanna',
#  'ushtobe',
#  'powell river',
#  'herat',
#  'shasta lake',
#  'petropavlovsk-kamchatskiy',
#  'kedrovoye',
#  'carupano',
#  'nehe',
#  'tumannyy',
#  'cochrane',
#  'port blair',
#  'moose factory',
#  'dakar',
#  'pafos',
#  'attawapiskat',
#  'kaura namoda',
#  'sorvag',
#  'ulaanbaatar',
#  'matara',
#  'oriximina',
#  'shahr-e babak',
#  'copala',
#  'togur',
#  'mehriz',
#  'utiroa',
#  'almaznyy',
#  'high level',
#  'villa rica',
#  'linping',
#  'olafsvik',
#  'afsin',
#  'sembakung',
#  'kant',
#  'jiddah',
#  'ajdabiya',
#  'huamachuco',
#  'turukhansk',
#  'nizhniy kuranakh',
#  'gorno-chuyskiy',
#  'thaba-tseka',
#  'arlit',
#  'darnah',
#  'san juan',
#  'mnogovershinnyy',
#  'terrace',
#  'taltal',
#  'riyadh',
#  'vrangel',
#  'daru',
#  'kisanga',
#  'dien bien',
#  'mawlaik',
#  'norrtalje',
#  'gilazi',
#  'les cayes',
#  'ndungu',
#  'smithers',
#  'biltine',
#  'klaksvik',
#  'wanning',
#  'san-pedro',
#  'longlac',
#  'sao felix do xingu',
#  'tarko-sale',
#  'tevaitoa',
#  'raton',
#  'banfora',
#  'marienburg',
#  'majene',
#  'tongren',
#  'mehamn',
#  'port moresby',
#  'ranau',
#  'bialystok',
#  'kelvington',
#  'comodoro rivadavia',
#  'caravelas',
#  'batagay-alyta',
#  'sakakah',
#  'eyl',
#  'manoel urbano',
#  'minggang',
#  'hambantota',
#  'ormara',
#  'fallon',
#  'najran',
#  'cuamba',
#  'igarka',
#  'swan river',
#  'dumas',
#  'umm kaddadah',
#  'khorixas',
#  'raga',
#  'presidente medici',
#  'yenagoa',
#  'vanimo',
#  'ngunguru',
#  'maneadero',
#  'dickinson',
#  'greystones',
#  'toropets',
#  'umzimvubu',
#  'mocambique',
#  'college',
#  'fereydun kenar',
#  'massaguet',
#  'varkkallai',
#  'bereda',
#  'porto franco',
#  'lexington park',
#  'san ramon',
#  'agutaya',
#  'sosnovo-ozerskoye',
#  'geraldton',
#  'sukheke',
#  'cestas',
#  'villaviciosa',
#  'harrismith',
#  'ponot',
#  'yerbogachen',
#  'ambilobe',
#  'vila franca do campo',
#  'gresham',
#  'paradwip',
#  'victor harbor',
#  'kidal',
#  'ciudad bolivar',
#  'andenes',
#  'provost',
#  'bargal',
#  'san policarpo',
#  'mackay',
#  'kintampo',
#  'birjand',
#  'carballo',
#  'inongo',
#  'ulaangom',
#  'santiago del estero',
#  'gigmoto',
#  'lata',
#  'northam',
#  'chernyshevsk',
#  'sayat',
#  'yanam',
#  'kargil',
#  'anori',
#  'lebyazhye',
#  'zabol',
#  'nancha',
#  'sibolga',
#  'chardara',
#  'kalabo',
#  'tres arroyos',
#  'karkaralinsk',
#  'velingara',
#  'oktyabrskoye',
#  'safaga',
#  'margate',
#  'pastavy',
#  'dolbeau',
#  'inuvik',
#  'seydi',
#  'topeka',
#  'taybad',
#  'montecristo',
#  'makakilo city',
#  'santa rita',
#  'tianpeng',
#  'koumac',
#  'tagusao']

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config1 import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description=city_weather["weather"][0]["description"]     
            
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Description":city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | albany
# Processing Record 2 of Set 1 | barcelos
# Processing Record 3 of Set 1 | saskylakh
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | krutinka
# Processing Record 6 of Set 1 | kapaa
# Processing Record 7 of Set 1 | karpogory
# Processing Record 8 of Set 1 | pisco
# Processing Record 9 of Set 1 | rio grande
# Processing Record 10 of Set 1 | cabo san lucas
# Processing Record 11 of Set 1 | bredasdorp
# Processing Record 12 of Set 1 | ortakoy
# Processing Record 13 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 14 of Set 1 | husavik
# Processing Record 15 of Set 1 | namibe
# Processing Record 16 of Set 1 | severo-kurilsk
# Processing Record 17 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 18 of Set 1 | sorland
# Processing Record 19 of Set 1 | port alfred
# Processing Record 20 of Set 1 | puli
# Processing Record 21 of Set 1 | sao raimundo nonato
# Processing Record 22 of Set 1 | clyde river
# Processing Record 23 of Set 1 | hermanus
# Processing Record 24 of Set 1 | zhangjiakou
# Processing Record 25 of Set 1 | la paz
# Processing Record 26 of Set 1 | puerto ayora
# Processing Record 27 of Set 1 | sarankhola
# Processing Record 28 of Set 1 | hobart
# Processing Record 29 of Set 1 | vaini
# Processing Record 30 of Set 1 | mar del plata
# Processing Record 31 of Set 1 | lebu
# Processing Record 32 of Set 1 | san jose de guanipa
# Processing Record 33 of Set 1 | ushuaia
# Processing Record 34 of Set 1 | narsaq
# Processing Record 35 of Set 1 | erzin
# Processing Record 36 of Set 1 | scarborough
# Processing Record 37 of Set 1 | dikson
# Processing Record 38 of Set 1 | tucuman
# Processing Record 39 of Set 1 | busselton
# Processing Record 40 of Set 1 | lompoc
# Processing Record 41 of Set 1 | half moon bay
# Processing Record 42 of Set 1 | atuona
# Processing Record 43 of Set 1 | vao
# Processing Record 44 of Set 1 | panguna
# Processing Record 45 of Set 1 | progreso
# Processing Record 46 of Set 1 | acapulco
# Processing Record 47 of Set 1 | maceio
# Processing Record 48 of Set 1 | souillac
# Processing Record 49 of Set 1 | chokurdakh
# Processing Record 50 of Set 1 | katsuura
# Processing Record 1 of Set 2 | yellowknife
# Processing Record 2 of Set 2 | butaritari
# Processing Record 3 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 4 of Set 2 | pevek
# Processing Record 5 of Set 2 | hithadhoo
# Processing Record 6 of Set 2 | mataura
# Processing Record 7 of Set 2 | kentau
# Processing Record 8 of Set 2 | hilo
# Processing Record 9 of Set 2 | sabha
# Processing Record 10 of Set 2 | port hedland
# Processing Record 11 of Set 2 | cape town
# Processing Record 12 of Set 2 | qaanaaq
# Processing Record 13 of Set 2 | bilma
# Processing Record 14 of Set 2 | cayenne
# Processing Record 15 of Set 2 | punta arenas
# Processing Record 16 of Set 2 | uaua
# Processing Record 17 of Set 2 | nanortalik
# Processing Record 18 of Set 2 | tuktoyaktuk
# Processing Record 19 of Set 2 | quatre cocos
# Processing Record 20 of Set 2 | constitucion
# Processing Record 21 of Set 2 | warwick
# Processing Record 22 of Set 2 | cockburn town
# Processing Record 23 of Set 2 | maniwaki
# Processing Record 24 of Set 2 | asau
# Processing Record 25 of Set 2 | mitu
# Processing Record 26 of Set 2 | ribeira grande
# Processing Record 27 of Set 2 | preobrazheniye
# Processing Record 28 of Set 2 | ponta do sol
# Processing Record 29 of Set 2 | jangaon
# Processing Record 30 of Set 2 | ritchie
# Processing Record 31 of Set 2 | raudeberg
# Processing Record 32 of Set 2 | puchezh
# Processing Record 33 of Set 2 | krasnokamensk
# Processing Record 34 of Set 2 | carnarvon
# Processing Record 35 of Set 2 | yinchuan
# Processing Record 36 of Set 2 | chicama
# Processing Record 37 of Set 2 | wuning
# Processing Record 38 of Set 2 | mashhad
# Processing Record 39 of Set 2 | inirida
# Processing Record 40 of Set 2 | ikalamavony
# Processing Record 41 of Set 2 | bluff
# Processing Record 42 of Set 2 | tazovskiy
# Processing Record 43 of Set 2 | tasiilaq
# Processing Record 44 of Set 2 | thompson
# Processing Record 45 of Set 2 | urdzhar
# City not found. Skipping...
# Processing Record 46 of Set 2 | jamestown
# Processing Record 47 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 48 of Set 2 | salalah
# Processing Record 49 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 50 of Set 2 | moerai
# Processing Record 1 of Set 3 | tuatapere
# Processing Record 2 of Set 3 | noumea
# Processing Record 3 of Set 3 | marsa matruh
# Processing Record 4 of Set 3 | torbay
# Processing Record 5 of Set 3 | camana
# Processing Record 6 of Set 3 | kisangani
# Processing Record 7 of Set 3 | plymouth
# Processing Record 8 of Set 3 | altea
# Processing Record 9 of Set 3 | naze
# Processing Record 10 of Set 3 | avera
# Processing Record 11 of Set 3 | cidreira
# Processing Record 12 of Set 3 | vila
# Processing Record 13 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 14 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 15 of Set 3 | sorong
# Processing Record 16 of Set 3 | shimoda
# Processing Record 17 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 18 of Set 3 | iqaluit
# Processing Record 19 of Set 3 | whitianga
# Processing Record 20 of Set 3 | nikolskoye
# Processing Record 21 of Set 3 | inta
# Processing Record 22 of Set 3 | kristiinankaupunki
# Processing Record 23 of Set 3 | miramar
# Processing Record 24 of Set 3 | hobyo
# Processing Record 25 of Set 3 | fairbanks
# Processing Record 26 of Set 3 | longyearbyen
# Processing Record 27 of Set 3 | pemba
# Processing Record 28 of Set 3 | mount gambier
# Processing Record 29 of Set 3 | bambanglipuro
# Processing Record 30 of Set 3 | dawlatabad
# Processing Record 31 of Set 3 | bengkulu
# Processing Record 32 of Set 3 | new norfolk
# Processing Record 33 of Set 3 | hofn
# Processing Record 34 of Set 3 | bambous virieux
# Processing Record 35 of Set 3 | correntina
# Processing Record 36 of Set 3 | belyy gorodok
# Processing Record 37 of Set 3 | celestun
# Processing Record 38 of Set 3 | asfi
# Processing Record 39 of Set 3 | nguruka
# Processing Record 40 of Set 3 | alofi
# Processing Record 41 of Set 3 | namatanai
# Processing Record 42 of Set 3 | tiksi
# Processing Record 43 of Set 3 | aklavik
# Processing Record 44 of Set 3 | paita
# Processing Record 45 of Set 3 | kansanshi
# Processing Record 46 of Set 3 | alice springs
# Processing Record 47 of Set 3 | cape canaveral
# Processing Record 48 of Set 3 | vigeland
# Processing Record 49 of Set 3 | klyuchi
# Processing Record 50 of Set 3 | victoria
# Processing Record 1 of Set 4 | barrow
# Processing Record 2 of Set 4 | luderitz
# Processing Record 3 of Set 4 | shelburne
# Processing Record 4 of Set 4 | nanakuli
# Processing Record 5 of Set 4 | bandarbeyla
# Processing Record 6 of Set 4 | mehar
# Processing Record 7 of Set 4 | sitka
# Processing Record 8 of Set 4 | encruzilhada do sul
# Processing Record 9 of Set 4 | dingle
# Processing Record 10 of Set 4 | ketchikan
# Processing Record 11 of Set 4 | vostok
# Processing Record 12 of Set 4 | mahebourg
# Processing Record 13 of Set 4 | castro
# Processing Record 14 of Set 4 | mogzon
# Processing Record 15 of Set 4 | isangel
# Processing Record 16 of Set 4 | berbera
# Processing Record 17 of Set 4 | cheyur
# City not found. Skipping...
# Processing Record 18 of Set 4 | kaitangata
# Processing Record 19 of Set 4 | korla
# Processing Record 20 of Set 4 | kloulklubed
# Processing Record 21 of Set 4 | vardo
# Processing Record 22 of Set 4 | tyrma
# Processing Record 23 of Set 4 | sotouboua
# Processing Record 24 of Set 4 | mayo
# Processing Record 25 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 26 of Set 4 | ijaki
# City not found. Skipping...
# Processing Record 27 of Set 4 | monrovia
# Processing Record 28 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 29 of Set 4 | diego de almagro
# Processing Record 30 of Set 4 | ballina
# Processing Record 31 of Set 4 | cherskiy
# Processing Record 32 of Set 4 | faanui
# Processing Record 33 of Set 4 | arraial do cabo
# Processing Record 34 of Set 4 | khatanga
# Processing Record 35 of Set 4 | ostrovnoy
# Processing Record 36 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 37 of Set 4 | kenai
# Processing Record 38 of Set 4 | hibbing
# Processing Record 39 of Set 4 | ust-kuyga
# Processing Record 40 of Set 4 | isiro
# Processing Record 41 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 42 of Set 4 | vanavara
# Processing Record 43 of Set 4 | chebarkul
# Processing Record 44 of Set 4 | chapeltown
# Processing Record 45 of Set 4 | gladstone
# Processing Record 46 of Set 4 | avarua
# Processing Record 47 of Set 4 | miles city
# Processing Record 48 of Set 4 | shenzhen
# Processing Record 49 of Set 4 | port elizabeth
# Processing Record 50 of Set 4 | saint-philippe
# Processing Record 1 of Set 5 | naryan-mar
# Processing Record 2 of Set 5 | grindavik
# Processing Record 3 of Set 5 | sioux lookout
# Processing Record 4 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 5 of Set 5 | coquimbo
# Processing Record 6 of Set 5 | khonuu
# City not found. Skipping...
# Processing Record 7 of Set 5 | nelson bay
# Processing Record 8 of Set 5 | lagoa
# Processing Record 9 of Set 5 | dalbandin
# Processing Record 10 of Set 5 | nara
# Processing Record 11 of Set 5 | upernavik
# Processing Record 12 of Set 5 | tsiroanomandidy
# Processing Record 13 of Set 5 | santa rosa
# Processing Record 14 of Set 5 | port keats
# Processing Record 15 of Set 5 | puntarenas
# Processing Record 16 of Set 5 | provideniya
# Processing Record 17 of Set 5 | cabedelo
# Processing Record 18 of Set 5 | bartica
# Processing Record 19 of Set 5 | iquique
# Processing Record 20 of Set 5 | gat
# Processing Record 21 of Set 5 | fortuna
# Processing Record 22 of Set 5 | kastamonu
# Processing Record 23 of Set 5 | lorengau
# Processing Record 24 of Set 5 | silver city
# Processing Record 25 of Set 5 | cairns
# Processing Record 26 of Set 5 | the pas
# Processing Record 27 of Set 5 | sur
# Processing Record 28 of Set 5 | te anau
# Processing Record 29 of Set 5 | broome
# Processing Record 30 of Set 5 | bethel
# Processing Record 31 of Set 5 | solnechnyy
# Processing Record 32 of Set 5 | ratnagiri
# Processing Record 33 of Set 5 | georgetown
# Processing Record 34 of Set 5 | warrington
# Processing Record 35 of Set 5 | hovd
# Processing Record 36 of Set 5 | saint george
# Processing Record 37 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 38 of Set 5 | chuy
# Processing Record 39 of Set 5 | san pedro
# Processing Record 40 of Set 5 | talcahuano
# Processing Record 41 of Set 5 | kjustendil
# Processing Record 42 of Set 5 | lima
# Processing Record 43 of Set 5 | kupang
# Processing Record 44 of Set 5 | laguna
# Processing Record 45 of Set 5 | sturgeon bay
# Processing Record 46 of Set 5 | ribas do rio pardo
# Processing Record 47 of Set 5 | falealupo
# City not found. Skipping...
# Processing Record 48 of Set 5 | talnakh
# Processing Record 49 of Set 5 | homa bay
# Processing Record 50 of Set 5 | taseyevo
# Processing Record 1 of Set 6 | ardatov
# Processing Record 2 of Set 6 | hasaki
# Processing Record 3 of Set 6 | saint-augustin
# Processing Record 4 of Set 6 | san isidro
# Processing Record 5 of Set 6 | nicoya
# Processing Record 6 of Set 6 | east london
# Processing Record 7 of Set 6 | ngukurr
# City not found. Skipping...
# Processing Record 8 of Set 6 | takhtamygda
# Processing Record 9 of Set 6 | hualmay
# Processing Record 10 of Set 6 | saint-pierre
# Processing Record 11 of Set 6 | belmonte
# Processing Record 12 of Set 6 | kangaatsiaq
# Processing Record 13 of Set 6 | kruisfontein
# Processing Record 14 of Set 6 | vestmannaeyjar
# Processing Record 15 of Set 6 | kemijarvi
# Processing Record 16 of Set 6 | sao joao da barra
# Processing Record 17 of Set 6 | grand centre
# City not found. Skipping...
# Processing Record 18 of Set 6 | porto novo
# Processing Record 19 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 20 of Set 6 | alta floresta
# Processing Record 21 of Set 6 | pascagoula
# Processing Record 22 of Set 6 | sinnamary
# Processing Record 23 of Set 6 | morges
# Processing Record 24 of Set 6 | mayya
# Processing Record 25 of Set 6 | buala
# Processing Record 26 of Set 6 | mormugao
# Processing Record 27 of Set 6 | saldanha
# Processing Record 28 of Set 6 | mae sai
# Processing Record 29 of Set 6 | kobryn
# Processing Record 30 of Set 6 | samarai
# Processing Record 31 of Set 6 | suicheng
# Processing Record 32 of Set 6 | coos bay
# Processing Record 33 of Set 6 | hay river
# Processing Record 34 of Set 6 | deputatskiy
# Processing Record 35 of Set 6 | deder
# Processing Record 36 of Set 6 | airai
# Processing Record 37 of Set 6 | yekaterinoslavka
# Processing Record 38 of Set 6 | yaan
# Processing Record 39 of Set 6 | seoul
# Processing Record 40 of Set 6 | asosa
# Processing Record 41 of Set 6 | codrington
# Processing Record 42 of Set 6 | san quintin
# Processing Record 43 of Set 6 | labutta
# City not found. Skipping...
# Processing Record 44 of Set 6 | baijiantan
# Processing Record 45 of Set 6 | mirabad
# Processing Record 46 of Set 6 | aybak
# City not found. Skipping...
# Processing Record 47 of Set 6 | muli
# Processing Record 48 of Set 6 | kitui
# Processing Record 49 of Set 6 | beringovskiy
# Processing Record 50 of Set 6 | nyurba
# Processing Record 1 of Set 7 | walla walla
# Processing Record 2 of Set 7 | tateyama
# Processing Record 3 of Set 7 | priargunsk
# Processing Record 4 of Set 7 | shirokiy
# Processing Record 5 of Set 7 | kalmunai
# Processing Record 6 of Set 7 | yumen
# Processing Record 7 of Set 7 | charleville-mezieres
# Processing Record 8 of Set 7 | sao gabriel da cachoeira
# Processing Record 9 of Set 7 | port lincoln
# Processing Record 10 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 11 of Set 7 | kodiak
# Processing Record 12 of Set 7 | puerto colombia
# Processing Record 13 of Set 7 | mantua
# Processing Record 14 of Set 7 | ahipara
# Processing Record 15 of Set 7 | nome
# Processing Record 16 of Set 7 | sakaiminato
# Processing Record 17 of Set 7 | chernukha
# Processing Record 18 of Set 7 | north myrtle beach
# Processing Record 19 of Set 7 | la ronge
# Processing Record 20 of Set 7 | bilibino
# Processing Record 21 of Set 7 | ternate
# Processing Record 22 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 23 of Set 7 | bowen
# Processing Record 24 of Set 7 | paranaiba
# Processing Record 25 of Set 7 | dharchula
# Processing Record 26 of Set 7 | grand gaube
# Processing Record 27 of Set 7 | norman wells
# Processing Record 28 of Set 7 | carutapera
# Processing Record 29 of Set 7 | port macquarie
# Processing Record 30 of Set 7 | houma
# Processing Record 31 of Set 7 | itaqui
# Processing Record 32 of Set 7 | marawi
# Processing Record 33 of Set 7 | xichang
# Processing Record 34 of Set 7 | puerto baquerizo moreno
# Processing Record 35 of Set 7 | mineral wells
# Processing Record 36 of Set 7 | kahului
# Processing Record 37 of Set 7 | minsk
# Processing Record 38 of Set 7 | san andres
# Processing Record 39 of Set 7 | turbat
# Processing Record 40 of Set 7 | irbil
# Processing Record 41 of Set 7 | kapuskasing
# Processing Record 42 of Set 7 | brae
# Processing Record 43 of Set 7 | benguela
# Processing Record 44 of Set 7 | kim
# Processing Record 45 of Set 7 | marzuq
# Processing Record 46 of Set 7 | kasongo-lunda
# Processing Record 47 of Set 7 | ust-nera
# Processing Record 48 of Set 7 | gushikawa
# Processing Record 49 of Set 7 | manta
# Processing Record 50 of Set 7 | aksu
# Processing Record 1 of Set 8 | touros
# Processing Record 2 of Set 8 | plettenberg bay
# Processing Record 3 of Set 8 | merauke
# Processing Record 4 of Set 8 | achisay
# City not found. Skipping...
# Processing Record 5 of Set 8 | parana
# Processing Record 6 of Set 8 | barreirinhas
# Processing Record 7 of Set 8 | petrolia
# Processing Record 8 of Set 8 | kerteh
# City not found. Skipping...
# Processing Record 9 of Set 8 | barreirinha
# Processing Record 10 of Set 8 | ampanihy
# Processing Record 11 of Set 8 | leningradskiy
# Processing Record 12 of Set 8 | jawhar
# Processing Record 13 of Set 8 | batsfjord
# Processing Record 14 of Set 8 | itaituba
# Processing Record 15 of Set 8 | bure
# Processing Record 16 of Set 8 | sao filipe
# Processing Record 17 of Set 8 | waddan
# Processing Record 18 of Set 8 | praia da vitoria
# Processing Record 19 of Set 8 | mufumbwe
# Processing Record 20 of Set 8 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 21 of Set 8 | lavrentiya
# Processing Record 22 of Set 8 | gannan
# Processing Record 23 of Set 8 | ilulissat
# Processing Record 24 of Set 8 | buchanan
# Processing Record 25 of Set 8 | okhotsk
# Processing Record 26 of Set 8 | trapani
# Processing Record 27 of Set 8 | falam
# Processing Record 28 of Set 8 | pontianak
# Processing Record 29 of Set 8 | yangliuqing
# Processing Record 30 of Set 8 | necochea
# Processing Record 31 of Set 8 | faya
# Processing Record 32 of Set 8 | vagur
# Processing Record 33 of Set 8 | mitsamiouli
# Processing Record 34 of Set 8 | anadyr
# Processing Record 35 of Set 8 | mapiripan
# Processing Record 36 of Set 8 | tsaratanana
# Processing Record 37 of Set 8 | hokitika
# Processing Record 38 of Set 8 | portland
# Processing Record 39 of Set 8 | barcelona
# Processing Record 40 of Set 8 | afmadu
# City not found. Skipping...
# Processing Record 41 of Set 8 | gemena
# Processing Record 42 of Set 8 | flinders
# Processing Record 43 of Set 8 | plerin
# Processing Record 44 of Set 8 | simao
# Processing Record 45 of Set 8 | ayagoz
# Processing Record 46 of Set 8 | atambua
# Processing Record 47 of Set 8 | dicabisagan
# Processing Record 48 of Set 8 | thohoyandou
# Processing Record 49 of Set 8 | pudozh
# Processing Record 50 of Set 8 | tautira
# Processing Record 1 of Set 9 | kudahuvadhoo
# Processing Record 2 of Set 9 | madang
# Processing Record 3 of Set 9 | tilichiki
# Processing Record 4 of Set 9 | poya
# Processing Record 5 of Set 9 | charters towers
# Processing Record 6 of Set 9 | krasnyy luch
# Processing Record 7 of Set 9 | lazaro cardenas
# Processing Record 8 of Set 9 | ohara
# Processing Record 9 of Set 9 | arman
# Processing Record 10 of Set 9 | davila
# Processing Record 11 of Set 9 | noyabrsk
# Processing Record 12 of Set 9 | taber
# Processing Record 13 of Set 9 | otane
# Processing Record 14 of Set 9 | atar
# Processing Record 15 of Set 9 | pasni
# Processing Record 16 of Set 9 | mount isa
# Processing Record 17 of Set 9 | kitale
# Processing Record 18 of Set 9 | zapolyarnyy
# Processing Record 19 of Set 9 | dubti
# Processing Record 20 of Set 9 | mackenzie
# Processing Record 21 of Set 9 | kavieng
# Processing Record 22 of Set 9 | ramnagar
# Processing Record 23 of Set 9 | galesong
# Processing Record 24 of Set 9 | ust-kulom
# Processing Record 25 of Set 9 | sal rei
# Processing Record 26 of Set 9 | sosva
# Processing Record 27 of Set 9 | puerto escondido
# Processing Record 28 of Set 9 | kuloy
# Processing Record 29 of Set 9 | kambove
# Processing Record 30 of Set 9 | gizo
# Processing Record 31 of Set 9 | doha
# Processing Record 32 of Set 9 | calama
# Processing Record 33 of Set 9 | taoudenni
# Processing Record 34 of Set 9 | labuhan
# Processing Record 35 of Set 9 | tungor
# Processing Record 36 of Set 9 | verkhoyansk
# Processing Record 37 of Set 9 | douglas
# Processing Record 38 of Set 9 | kaseda
# Processing Record 39 of Set 9 | santa cruz
# Processing Record 40 of Set 9 | riosucio
# Processing Record 41 of Set 9 | cap malheureux
# Processing Record 42 of Set 9 | obera
# Processing Record 43 of Set 9 | nishihara
# Processing Record 44 of Set 9 | poum
# Processing Record 45 of Set 9 | kongolo
# Processing Record 46 of Set 9 | pangnirtung
# Processing Record 47 of Set 9 | abha
# Processing Record 48 of Set 9 | vila velha
# Processing Record 49 of Set 9 | tessalit
# Processing Record 50 of Set 9 | berdigestyakh
# Processing Record 1 of Set 10 | hongjiang
# Processing Record 2 of Set 10 | goteborg
# City not found. Skipping...
# Processing Record 3 of Set 10 | vanderhoof
# Processing Record 4 of Set 10 | ahuimanu
# Processing Record 5 of Set 10 | jumla
# Processing Record 6 of Set 10 | ndele
# Processing Record 7 of Set 10 | oranjemund
# Processing Record 8 of Set 10 | mirador
# Processing Record 9 of Set 10 | nouakchott
# Processing Record 10 of Set 10 | roma
# Processing Record 11 of Set 10 | novobirilyussy
# Processing Record 12 of Set 10 | senneterre
# Processing Record 13 of Set 10 | morondava
# Processing Record 14 of Set 10 | omboue
# Processing Record 15 of Set 10 | aswan
# Processing Record 16 of Set 10 | sawakin
# Processing Record 17 of Set 10 | kharan
# Processing Record 18 of Set 10 | san giovanni rotondo
# Processing Record 19 of Set 10 | pacific grove
# Processing Record 20 of Set 10 | baiyin
# Processing Record 21 of Set 10 | haines junction
# Processing Record 22 of Set 10 | methoni
# Processing Record 23 of Set 10 | auch
# Processing Record 24 of Set 10 | dunedin
# Processing Record 25 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 26 of Set 10 | camacha
# Processing Record 27 of Set 10 | verkhnyaya inta
# Processing Record 28 of Set 10 | chute-aux-outardes
# Processing Record 29 of Set 10 | srednekolymsk
# Processing Record 30 of Set 10 | aquiraz
# Processing Record 31 of Set 10 | kodinsk
# Processing Record 32 of Set 10 | grand-santi
# Processing Record 33 of Set 10 | tomatlan
# Processing Record 34 of Set 10 | kavos
# Processing Record 35 of Set 10 | pine bluff
# Processing Record 36 of Set 10 | tukrah
# Processing Record 37 of Set 10 | manturovo
# Processing Record 38 of Set 10 | othonoi
# City not found. Skipping...
# Processing Record 39 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 40 of Set 10 | bathsheba
# Processing Record 41 of Set 10 | honiara
# Processing Record 42 of Set 10 | jega
# Processing Record 43 of Set 10 | belaya gora
# Processing Record 44 of Set 10 | smolenskoye
# Processing Record 45 of Set 10 | roald
# Processing Record 46 of Set 10 | tadine
# Processing Record 47 of Set 10 | nuevitas
# Processing Record 48 of Set 10 | bien hoa
# Processing Record 49 of Set 10 | hamilton
# Processing Record 50 of Set 10 | nizwa
# Processing Record 1 of Set 11 | coihaique
# Processing Record 2 of Set 11 | ouadda
# Processing Record 3 of Set 11 | mabaruma
# Processing Record 4 of Set 11 | botou
# Processing Record 5 of Set 11 | mareeba
# Processing Record 6 of Set 11 | tubmanburg
# Processing Record 7 of Set 11 | nuqui
# Processing Record 8 of Set 11 | havre-saint-pierre
# Processing Record 9 of Set 11 | chapais
# Processing Record 10 of Set 11 | curup
# Processing Record 11 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 12 of Set 11 | bud
# Processing Record 13 of Set 11 | beinamar
# Processing Record 14 of Set 11 | berlevag
# Processing Record 15 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 16 of Set 11 | terracina
# Processing Record 17 of Set 11 | ostersund
# Processing Record 18 of Set 11 | yulara
# Processing Record 19 of Set 11 | san patricio
# Processing Record 20 of Set 11 | rawson
# Processing Record 21 of Set 11 | jibuti
# Processing Record 22 of Set 11 | mandalgovi
# Processing Record 23 of Set 11 | north bend
# Processing Record 24 of Set 11 | tignere
# Processing Record 25 of Set 11 | doka
# Processing Record 26 of Set 11 | port-cartier
# Processing Record 27 of Set 11 | nantucket
# Processing Record 28 of Set 11 | liuhe
# Processing Record 29 of Set 11 | kavaratti
# Processing Record 30 of Set 11 | port alberni
# Processing Record 31 of Set 11 | esperance
# Processing Record 32 of Set 11 | saint anthony
# Processing Record 33 of Set 11 | zhigansk
# Processing Record 34 of Set 11 | changtu
# Processing Record 35 of Set 11 | hatillo
# Processing Record 36 of Set 11 | noshiro
# Processing Record 37 of Set 11 | angermunde
# Processing Record 38 of Set 11 | morant bay
# Processing Record 39 of Set 11 | malakal
# Processing Record 40 of Set 11 | osypenko
# Processing Record 41 of Set 11 | sandusky
# Processing Record 42 of Set 11 | buariki
# City not found. Skipping...
# Processing Record 43 of Set 11 | padre bernardo
# Processing Record 44 of Set 11 | tura
# Processing Record 45 of Set 11 | novyy starodub
# Processing Record 46 of Set 11 | curuca
# Processing Record 47 of Set 11 | botshabelo
# Processing Record 48 of Set 11 | nampula
# Processing Record 49 of Set 11 | tubinskiy
# Processing Record 50 of Set 11 | kieta
# Processing Record 1 of Set 12 | yokadouma
# Processing Record 2 of Set 12 | skibbereen
# Processing Record 3 of Set 12 | satitoa
# City not found. Skipping...
# Processing Record 4 of Set 12 | shingu
# Processing Record 5 of Set 12 | baracoa
# Processing Record 6 of Set 12 | lucapa
# Processing Record 7 of Set 12 | lumphat
# Processing Record 8 of Set 12 | camacupa
# Processing Record 9 of Set 12 | chengde
# Processing Record 10 of Set 12 | kununurra
# Processing Record 11 of Set 12 | kaeo
# Processing Record 12 of Set 12 | hurghada
# Processing Record 13 of Set 12 | asyut
# Processing Record 14 of Set 12 | pasighat
# Processing Record 15 of Set 12 | the valley
# Processing Record 16 of Set 12 | springbok
# Processing Record 17 of Set 12 | vestmanna
# Processing Record 18 of Set 12 | ushtobe
# Processing Record 19 of Set 12 | powell river
# Processing Record 20 of Set 12 | herat
# Processing Record 21 of Set 12 | shasta lake
# Processing Record 22 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 23 of Set 12 | kedrovoye
# Processing Record 24 of Set 12 | carupano
# Processing Record 25 of Set 12 | nehe
# Processing Record 26 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 27 of Set 12 | cochrane
# Processing Record 28 of Set 12 | port blair
# Processing Record 29 of Set 12 | moose factory
# Processing Record 30 of Set 12 | dakar
# Processing Record 31 of Set 12 | pafos
# Processing Record 32 of Set 12 | attawapiskat
# City not found. Skipping...
# Processing Record 33 of Set 12 | kaura namoda
# Processing Record 34 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 35 of Set 12 | ulaanbaatar
# Processing Record 36 of Set 12 | matara
# Processing Record 37 of Set 12 | oriximina
# Processing Record 38 of Set 12 | shahr-e babak
# Processing Record 39 of Set 12 | copala
# Processing Record 40 of Set 12 | togur
# Processing Record 41 of Set 12 | mehriz
# Processing Record 42 of Set 12 | utiroa
# City not found. Skipping...
# Processing Record 43 of Set 12 | almaznyy
# Processing Record 44 of Set 12 | high level
# Processing Record 45 of Set 12 | villa rica
# Processing Record 46 of Set 12 | linping
# Processing Record 47 of Set 12 | olafsvik
# Processing Record 48 of Set 12 | afsin
# Processing Record 49 of Set 12 | sembakung
# Processing Record 50 of Set 12 | kant
# Processing Record 1 of Set 13 | jiddah
# City not found. Skipping...
# Processing Record 2 of Set 13 | ajdabiya
# Processing Record 3 of Set 13 | huamachuco
# Processing Record 4 of Set 13 | turukhansk
# Processing Record 5 of Set 13 | nizhniy kuranakh
# Processing Record 6 of Set 13 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 7 of Set 13 | thaba-tseka
# Processing Record 8 of Set 13 | arlit
# Processing Record 9 of Set 13 | darnah
# Processing Record 10 of Set 13 | san juan
# Processing Record 11 of Set 13 | mnogovershinnyy
# Processing Record 12 of Set 13 | terrace
# Processing Record 13 of Set 13 | taltal
# Processing Record 14 of Set 13 | riyadh
# Processing Record 15 of Set 13 | vrangel
# Processing Record 16 of Set 13 | daru
# Processing Record 17 of Set 13 | kisanga
# Processing Record 18 of Set 13 | dien bien
# City not found. Skipping...
# Processing Record 19 of Set 13 | mawlaik
# Processing Record 20 of Set 13 | norrtalje
# Processing Record 21 of Set 13 | gilazi
# City not found. Skipping...
# Processing Record 22 of Set 13 | les cayes
# Processing Record 23 of Set 13 | ndungu
# Processing Record 24 of Set 13 | smithers
# Processing Record 25 of Set 13 | biltine
# Processing Record 26 of Set 13 | klaksvik
# Processing Record 27 of Set 13 | wanning
# Processing Record 28 of Set 13 | san-pedro
# Processing Record 29 of Set 13 | longlac
# City not found. Skipping...
# Processing Record 30 of Set 13 | sao felix do xingu
# Processing Record 31 of Set 13 | tarko-sale
# Processing Record 32 of Set 13 | tevaitoa
# Processing Record 33 of Set 13 | raton
# Processing Record 34 of Set 13 | banfora
# Processing Record 35 of Set 13 | marienburg
# Processing Record 36 of Set 13 | majene
# Processing Record 37 of Set 13 | tongren
# Processing Record 38 of Set 13 | mehamn
# Processing Record 39 of Set 13 | port moresby
# Processing Record 40 of Set 13 | ranau
# Processing Record 41 of Set 13 | bialystok
# Processing Record 42 of Set 13 | kelvington
# Processing Record 43 of Set 13 | comodoro rivadavia
# Processing Record 44 of Set 13 | caravelas
# Processing Record 45 of Set 13 | batagay-alyta
# Processing Record 46 of Set 13 | sakakah
# Processing Record 47 of Set 13 | eyl
# Processing Record 48 of Set 13 | manoel urbano
# Processing Record 49 of Set 13 | minggang
# Processing Record 50 of Set 13 | hambantota
# Processing Record 1 of Set 14 | ormara
# Processing Record 2 of Set 14 | fallon
# Processing Record 3 of Set 14 | najran
# Processing Record 4 of Set 14 | cuamba
# Processing Record 5 of Set 14 | igarka
# Processing Record 6 of Set 14 | swan river
# Processing Record 7 of Set 14 | dumas
# Processing Record 8 of Set 14 | umm kaddadah
# Processing Record 9 of Set 14 | khorixas
# Processing Record 10 of Set 14 | raga
# Processing Record 11 of Set 14 | presidente medici
# Processing Record 12 of Set 14 | yenagoa
# Processing Record 13 of Set 14 | vanimo
# Processing Record 14 of Set 14 | ngunguru
# Processing Record 15 of Set 14 | maneadero
# Processing Record 16 of Set 14 | dickinson
# Processing Record 17 of Set 14 | greystones
# Processing Record 18 of Set 14 | toropets
# Processing Record 19 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 20 of Set 14 | mocambique
# City not found. Skipping...
# Processing Record 21 of Set 14 | college
# Processing Record 22 of Set 14 | fereydun kenar
# Processing Record 23 of Set 14 | massaguet
# Processing Record 24 of Set 14 | varkkallai
# Processing Record 25 of Set 14 | bereda
# Processing Record 26 of Set 14 | porto franco
# Processing Record 27 of Set 14 | lexington park
# Processing Record 28 of Set 14 | san ramon
# Processing Record 29 of Set 14 | agutaya
# Processing Record 30 of Set 14 | sosnovo-ozerskoye
# Processing Record 31 of Set 14 | geraldton
# Processing Record 32 of Set 14 | sukheke
# City not found. Skipping...
# Processing Record 33 of Set 14 | cestas
# Processing Record 34 of Set 14 | villaviciosa
# Processing Record 35 of Set 14 | harrismith
# Processing Record 36 of Set 14 | ponot
# Processing Record 37 of Set 14 | yerbogachen
# Processing Record 38 of Set 14 | ambilobe
# Processing Record 39 of Set 14 | vila franca do campo
# Processing Record 40 of Set 14 | gresham
# Processing Record 41 of Set 14 | paradwip
# City not found. Skipping...
# Processing Record 42 of Set 14 | victor harbor
# Processing Record 43 of Set 14 | kidal
# Processing Record 44 of Set 14 | ciudad bolivar
# Processing Record 45 of Set 14 | andenes
# Processing Record 46 of Set 14 | provost
# Processing Record 47 of Set 14 | bargal
# City not found. Skipping...
# Processing Record 48 of Set 14 | san policarpo
# Processing Record 49 of Set 14 | mackay
# Processing Record 50 of Set 14 | kintampo
# Processing Record 1 of Set 15 | birjand
# Processing Record 2 of Set 15 | carballo
# Processing Record 3 of Set 15 | inongo
# Processing Record 4 of Set 15 | ulaangom
# Processing Record 5 of Set 15 | santiago del estero
# Processing Record 6 of Set 15 | gigmoto
# Processing Record 7 of Set 15 | lata
# Processing Record 8 of Set 15 | northam
# Processing Record 9 of Set 15 | chernyshevsk
# Processing Record 10 of Set 15 | sayat
# Processing Record 11 of Set 15 | yanam
# Processing Record 12 of Set 15 | kargil
# Processing Record 13 of Set 15 | anori
# Processing Record 14 of Set 15 | lebyazhye
# Processing Record 15 of Set 15 | zabol
# Processing Record 16 of Set 15 | nancha
# Processing Record 17 of Set 15 | sibolga
# Processing Record 18 of Set 15 | chardara
# Processing Record 19 of Set 15 | kalabo
# Processing Record 20 of Set 15 | tres arroyos
# Processing Record 21 of Set 15 | karkaralinsk
# City not found. Skipping...
# Processing Record 22 of Set 15 | velingara
# Processing Record 23 of Set 15 | oktyabrskoye
# Processing Record 24 of Set 15 | safaga
# Processing Record 25 of Set 15 | margate
# Processing Record 26 of Set 15 | pastavy
# Processing Record 27 of Set 15 | dolbeau
# City not found. Skipping...
# Processing Record 28 of Set 15 | inuvik
# Processing Record 29 of Set 15 | seydi
# Processing Record 30 of Set 15 | topeka
# Processing Record 31 of Set 15 | taybad
# Processing Record 32 of Set 15 | montecristo
# Processing Record 33 of Set 15 | makakilo city
# Processing Record 34 of Set 15 | santa rita
# Processing Record 35 of Set 15 | tianpeng
# Processing Record 36 of Set 15 | koumac
# Processing Record 37 of Set 15 | tagusao
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 683

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Albany  42.6001  -73.9662     42.22        81          58
# 1        Barcelos  41.5388   -8.6151     62.74        88          48
# 2       Saskylakh  71.9167  114.0833      1.49        95          38
# 3         Rikitea -23.1203 -134.9692     71.08        71         100
# 4        Krutinka  56.0055   71.5113     39.58        86         100
# 5           Kapaa  22.0752 -159.3190     75.18        83         100
# 6       Karpogory  64.0019   44.4451     34.63        96         100
# 7           Pisco -13.7000  -76.2167     59.05        82          65
# 8      Rio Grande -32.0350  -52.0986     60.71        94           3
# 9  Cabo San Lucas  22.8909 -109.9124     80.62        84          26
#
#    Wind Speed Country                 Date       Description
# 0        6.69      US  2022-10-20 03:21:31     broken clouds
# 1       13.85      PT  2022-10-20 03:27:36  scattered clouds
# 2        2.98      RU  2022-10-20 03:25:58  scattered clouds
# 3       18.34      PF  2022-10-20 03:23:27   overcast clouds
# 4       10.29      RU  2022-10-20 03:27:37   overcast clouds
# 5       18.41      US  2022-10-20 03:21:31   overcast clouds
# 6       12.91      RU  2022-10-20 03:25:40        light snow
# 7        6.91      PE  2022-10-20 03:24:42     broken clouds
# 8        5.93      BR  2022-10-20 03:27:37         clear sky
# 9       11.30      MX  2022-10-20 03:21:06  scattered clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Date', 'Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Description"]

# Recreate the DataFrame by using the new column order
city_data_df=city_data_df[new]

# Display sample data
city_data_df.head()
# Out:
#         City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Albany      US  42.6001  -73.9662     42.22        81          58
# 1   Barcelos      PT  41.5388   -8.6151     62.74        88          48
# 2  Saskylakh      RU  71.9167  114.0833      1.49        95          38
# 3    Rikitea      PF -23.1203 -134.9692     71.08        71         100
# 4   Krutinka      RU  56.0055   71.5113     39.58        86         100
#
#    Wind Speed       Description
# 0        6.69     broken clouds
# 1       13.85  scattered clouds
# 2        2.98  scattered clouds
# 3       18.34   overcast clouds
# 4       10.29   overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City            object
# Country         object
# Lat            float64
# Lng            float64
# Max Temp       float64
# Humidity         int64
# Cloudiness       int64
# Wind Speed     float64
# Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
